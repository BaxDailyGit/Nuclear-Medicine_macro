# %%
import os
d_path_list=[]
dir_path = "C:\\Users\\ajounm\\Desktop\\BRCL_PNG\\convert"

for (root, directories, files) in os.walk(dir_path):
    for d in directories:
        d_path = os.path.join(root, d)
        print(d_path)
        d_path_list.append(d_path)
        
        
    for file in files:
        file_path = os.path.join(root, file)
        print(file_path)
# Out:
# C:\Users\ajounm\Desktop\BRCL_PNG\convert\0003481_20220913
# C:\Users\ajounm\Desktop\BRCL_PNG\convert\0010945_20220913
# C:\Users\ajounm\Desktop\BRCL_PNG\convert\0018475_20220913
# C:\Users\ajounm\Desktop\BRCL_PNG\convert\0031122_20220913
# C:\Users\ajounm\Desktop\BRCL_PNG\convert\0037070_20220913
# C:\Users\ajounm\Desktop\BRCL_PNG\convert\0040437_20220913
# C:\Users\ajounm\Desktop\BRCL_PNG\convert\0047792_20220913
# C:\Users\ajounm\Desktop\BRCL_PNG\convert\0051317_20220913
# C:\Users\ajounm\Desktop\BRCL_PNG\convert\0057456_20220913
# C:\Users\ajounm\Desktop\BRCL_PNG\convert\0061994_20220913
# C:\Users\ajounm\Desktop\BRCL_PNG\convert\0067252_20220913
# C:\Users\ajounm\Desktop\BRCL_PNG\convert\0072237_20220913
# C:\Users\ajounm\Desktop\BRCL_PNG\convert\0086339_20220913
# C:\Users\ajounm\Desktop\BRCL_PNG\convert\0095101_20220913
# C:\Users\ajounm\Desktop\BRCL_PNG\convert\0103855_20220913
# C:\Users\ajounm\Desktop\BRCL_PNG\convert\0104290_20220913
# ...
